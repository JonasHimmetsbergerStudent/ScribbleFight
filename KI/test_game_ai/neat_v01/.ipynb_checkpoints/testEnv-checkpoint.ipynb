# %%
from ipynb.fs.full.neatFile import *

if __name__ == '__main__':
    run()
# Out:
#  ****** Running generation 0 ******
#
# Population's average fitness: -127.92983 stdev: 25.58087
# Best fitness: -98.38074 - size: (6, 152) - species 1 - id 19
# Average adjusted fitness: 0.778
# Mean genetic distance 2.031, standard deviation 0.272
# Population of 200 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    0   200    -98.4    0.778     0
# Total extinctions: 0
# Generation time: 15.323 sec
#
#  ****** Running generation 1 ******
#
# Population's average fitness: -125.13515 stdev: 25.85626
# Best fitness: -97.92962 - size: (6, 152) - species 1 - id 19
# Average adjusted fitness: 0.768
# Mean genetic distance 1.679, standard deviation 0.210
# Population of 200 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    1   200    -97.9    0.768     0
# Total extinctions: 0
# Generation time: 16.705 sec (16.014 average)
#
#  ****** Running generation 2 ******
#
# Population's average fitness: -119.29328 stdev: 23.57085
# Best fitness: -94.18325 - size: (4, 96) - species 1 - id 500
# Average adjusted fitness: 0.822
# Mean genetic distance 1.577, standard deviation 0.171
# Population of 200 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    2   200    -94.2    0.822     0
# Total extinctions: 0
# Generation time: 13.579 sec (15.202 average)
#
#  ****** Running generation 3 ******
#
# Population's average fitness: -114.87573 stdev: 19.43403
# Best fitness: -98.34265 - size: (6, 152) - species 1 - id 585
# Average adjusted fitness: 0.795
# Mean genetic distance 1.587, standard deviation 0.174
# Population of 200 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    3   200    -98.3    0.795     1
# Total extinctions: 0
# Generation time: 8.735 sec (13.585 average)
#
#  ****** Running generation 4 ******
#
# Population's average fitness: -114.21270 stdev: 20.12548
# Best fitness: -80.91273 - size: (5, 122) - species 1 - id 952
# Average adjusted fitness: 0.680
# Mean genetic distance 1.530, standard deviation 0.173
# Population of 200 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    4   200    -80.9    0.680     0
# Total extinctions: 0
# Generation time: 10.060 sec (12.880 average)
#
#  ****** Running generation 5 ******
#
# Population's average fitness: -113.35721 stdev: 21.50005
# Best fitness: -91.82693 - size: (7, 149) - species 1 - id 1036
# Average adjusted fitness: 0.769
# Mean genetic distance 1.653, standard deviation 0.154
# Population of 200 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    5   200    -91.8    0.769     1
# Total extinctions: 0
# Generation time: 11.769 sec (12.695 average)
#
#  ****** Running generation 6 ******
#
# Population's average fitness: -104.58027 stdev: 20.66961
# Best fitness: -91.72579 - size: (7, 146) - species 1 - id 1326
# Average adjusted fitness: 0.860
# Mean genetic distance 1.624, standard deviation 0.223
# Population of 200 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    6   200    -91.7    0.860     2
# Total extinctions: 0
# Generation time: 10.003 sec (12.311 average)
#
#  ****** Running generation 7 ******
#
# Population's average fitness: -97.61947 stdev: 15.43542
# Best fitness: -91.79264 - size: (7, 141) - species 1 - id 1442
# Average adjusted fitness: 0.936
# Mean genetic distance 1.530, standard deviation 0.219
# Population of 200 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    7   200    -91.8    0.936     3
# Total extinctions: 0
# Generation time: 8.420 sec (11.824 average)
#
#  ****** Running generation 8 ******
#
# Population's average fitness: -97.10313 stdev: 14.76421
# Best fitness: -91.78644 - size: (8, 145) - species 1 - id 1749
# Average adjusted fitness: 0.942
# Mean genetic distance 1.561, standard deviation 0.228
# Population of 200 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    8   200    -91.8    0.942     4
# Total extinctions: 0
# Generation time: 7.654 sec (11.361 average)
#
#  ****** Running generation 9 ******
#
# Population's average fitness: -95.32356 stdev: 12.12223
# Best fitness: -78.07289 - size: (7, 116) - species 1 - id 1956
# Average adjusted fitness: 0.833
# Mean genetic distance 1.735, standard deviation 0.253
# Population of 200 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    9   200    -78.1    0.833     0
# Total extinctions: 0
# Generation time: 7.577 sec (10.983 average)
#
#  ****** Running generation 10 ******
#
# Population's average fitness: -98.99615 stdev: 16.95899
# Best fitness: -91.78907 - size: (10, 145) - species 1 - id 2012
# Average adjusted fitness: 0.919
# Mean genetic distance 1.875, standard deviation 0.282
# Population of 200 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   10   200    -91.8    0.919     1
# Total extinctions: 0
# Generation time: 7.895 sec (10.240 average)
#
#  ****** Running generation 11 ******
#
# Population's average fitness: -97.58014 stdev: 16.18932
# Best fitness: -91.80017 - size: (9, 144) - species 1 - id 2226
# Average adjusted fitness: 0.937
# Mean genetic distance 1.942, standard deviation 0.291
# Population of 200 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   11   200    -91.8    0.937     2
# Total extinctions: 0
# Generation time: 7.837 sec (9.353 average)
#
#  ****** Running generation 12 ******
#
# Population's average fitness: -98.34364 stdev: 18.09307
# Best fitness: -49.23191 - size: (10, 136) - species 1 - id 2385
# Average adjusted fitness: 0.649
# Mean genetic distance 1.959, standard deviation 0.281
# Population of 200 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   12   200    -49.2    0.649     0
# Total extinctions: 0
# Generation time: 8.761 sec (8.871 average)
#
#  ****** Running generation 13 ******
#
# Population's average fitness: -97.09297 stdev: 15.05339
# Best fitness: -37.93794 - size: (7, 114) - species 1 - id 2429
# Average adjusted fitness: 0.587
# Mean genetic distance 1.942, standard deviation 0.296
# Population of 200 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   13   200    -37.9    0.587     0
# Total extinctions: 0
# Generation time: 6.511 sec (8.649 average)
#
#  ****** Running generation 14 ******
#
# Population's average fitness: -98.22373 stdev: 19.97265
# Best fitness: -39.77568 - size: (7, 109) - species 1 - id 2793
# Average adjusted fitness: 0.595
# Mean genetic distance 1.981, standard deviation 0.242
# Population of 200 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   14   200    -39.8    0.595     1
# Total extinctions: 0
# Generation time: 8.755 sec (8.518 average)
#
#  ****** Running generation 15 ******
#
# Population's average fitness: -97.21997 stdev: 23.54900
# Best fitness: -25.39834 - size: (7, 110) - species 1 - id 2942
# Average adjusted fitness: 0.571
# Mean genetic distance 2.005, standard deviation 0.252
# Population of 200 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   15   200    -25.4    0.571     0
# Total extinctions: 0
# Generation time: 9.869 sec (8.328 average)
#
#  ****** Running generation 16 ******
#
# Population's average fitness: -87.72347 stdev: 27.65526
# Best fitness: -25.97225 - size: (7, 110) - species 1 - id 2942
# Average adjusted fitness: 0.602
# Mean genetic distance 1.799, standard deviation 0.232
# Population of 200 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   16   200    -26.0    0.602     1
# Total extinctions: 0
# Generation time: 16.960 sec (9.024 average)
#
#  ****** Running generation 17 ******
#
# Population's average fitness: -72.37094 stdev: 40.29248
# Best fitness: 0.81450 - size: (7, 107) - species 1 - id 3420
# Average adjusted fitness: 0.612
# Mean genetic distance 1.765, standard deviation 0.252
# Population of 200 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   17   200      0.8    0.612     0
# Total extinctions: 0
# Generation time: 31.007 sec (11.282 average)
#
#  ****** Running generation 18 ******
# Population's average fitness: -69.74076 stdev: 40.12751
# Best fitness: -14.10834 - size: (8, 105) - species 1 - id 3712
# Average adjusted fitness: 0.676
# Mean genetic distance 1.854, standard deviation 0.244
# Population of 200 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   18   200    -14.1    0.676     1
# Total extinctions: 0
# Generation time: 32.006 sec (13.718 average)
#
#  ****** Running generation 19 ******
#
# Population's average fitness: -72.93963 stdev: 38.75538
# Best fitness: 0.65168 - size: (7, 104) - species 1 - id 3906
# Average adjusted fitness: 0.603
# Mean genetic distance 1.713, standard deviation 0.234
# Population of 200 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   19   200      0.7    0.603     2
# Total extinctions: 0
# Generation time: 30.462 sec (16.006 average)
#
#  ****** Running generation 20 ******
#
# Population's average fitness: -73.65137 stdev: 40.99715
# Best fitness: 5.20333 - size: (7, 102) - species 1 - id 4133
# Average adjusted fitness: 0.577
# Mean genetic distance 1.576, standard deviation 0.237
# Population of 200 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   20   200      5.2    0.577     0
# Total extinctions: 0
# Generation time: 31.250 sec (18.342 average)
#
#  ****** Running generation 21 ******
#
# Population's average fitness: -69.90605 stdev: 39.33255
# Best fitness: 0.15341 - size: (7, 98) - species 1 - id 4178
# Average adjusted fitness: 0.613
# Mean genetic distance 1.522, standard deviation 0.254
# Population of 200 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   21   200      0.2    0.613     1
# Total extinctions: 0
# Generation time: 37.267 sec (21.285 average)
#
#  ****** Running generation 22 ******
#
# Population's average fitness: -78.01500 stdev: 40.86411
# Best fitness: -7.77027 - size: (7, 98) - species 1 - id 4470
# Average adjusted fitness: 0.604
# Mean genetic distance 1.634, standard deviation 0.247
# Population of 200 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   22   200     -7.8    0.604     2
# Total extinctions: 0
# Generation time: 32.309 sec (23.639 average)
#
#  ****** Running generation 23 ******
#
# Population's average fitness: -74.80104 stdev: 41.85752
# Best fitness: 33.38110 - size: (7, 101) - species 1 - id 4594
#
# Best individual in generation 23 meets fitness threshold - complexity: (7, 101)
# Key: 4594
# Fitness: 33.381096419944335
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=0.9975383684126703, response=1.0, activation=tanh, aggregation=sum)
# 	1 DefaultNodeGene(key=1, bias=1.9991927238204916, response=1.0, activation=tanh, aggregation=sum)
# 	2 DefaultNodeGene(key=2, bias=0.11947868123539673, response=1.0, activation=tanh, aggregation=sum)
# 	3 DefaultNodeGene(key=3, bias=-0.13281735159471736, response=1.0, activation=tanh, aggregation=sum)
# 	323 DefaultNodeGene(key=323, bias=-0.06666967237055872, response=1.0, activation=tanh, aggregation=sum)
# 	524 DefaultNodeGene(key=524, bias=-1.2530759943223775, response=1.0, activation=tanh, aggregation=sum)
# 	874 DefaultNodeGene(key=874, bias=-1.6921654578967358, response=1.0, activation=tanh, aggregation=sum)
# Connections:
# 	DefaultConnectionGene(key=(-24, 0), weight=-1.1406256184851231, enabled=True)
# 	DefaultConnectionGene(key=(-24, 1), weight=3.251320429755837, enabled=True)
# 	DefaultConnectionGene(key=(-24, 2), weight=-0.7870127911546994, enabled=True)
# 	DefaultConnectionGene(key=(-24, 3), weight=-0.8474898556497331, enabled=False)
# 	DefaultConnectionGene(key=(-24, 323), weight=0.059553780930359554, enabled=True)
# 	DefaultConnectionGene(key=(-24, 874), weight=-0.3468980411374187, enabled=False)
# 	DefaultConnectionGene(key=(-23, 0), weight=-0.47765379106018546, enabled=True)
# 	DefaultConnectionGene(key=(-23, 1), weight=-5.618403578773833, enabled=True)
# 	DefaultConnectionGene(key=(-23, 2), weight=0.584883378958578, enabled=True)
# 	DefaultConnectionGene(key=(-23, 3), weight=-0.1719380311727522, enabled=True)
# 	DefaultConnectionGene(key=(-23, 323), weight=0.23276897959209253, enabled=True)
# 	DefaultConnectionGene(key=(-22, 0), weight=0.9758133874088885, enabled=True)
# 	DefaultConnectionGene(key=(-22, 1), weight=2.7938161852456505, enabled=True)
# 	DefaultConnectionGene(key=(-22, 2), weight=0.2837549043133025, enabled=True)
# 	DefaultConnectionGene(key=(-22, 3), weight=2.5154866995868304, enabled=False)
# 	DefaultConnectionGene(key=(-22, 323), weight=0.14003497549211444, enabled=True)
# 	DefaultConnectionGene(key=(-21, 0), weight=1.4725031121176215, enabled=True)
# 	DefaultConnectionGene(key=(-21, 1), weight=2.323707686383643, enabled=True)
# 	DefaultConnectionGene(key=(-21, 2), weight=0.7839820739530552, enabled=True)
# 	DefaultConnectionGene(key=(-21, 3), weight=1.0975737470844278, enabled=True)
# 	DefaultConnectionGene(key=(-21, 323), weight=1.3128739292421425, enabled=True)
# 	DefaultConnectionGene(key=(-20, 0), weight=3.7233536656403925, enabled=True)
# 	DefaultConnectionGene(key=(-20, 1), weight=0.43802851629688977, enabled=False)
# 	DefaultConnectionGene(key=(-20, 2), weight=-3.537614287824832, enabled=False)
# 	DefaultConnectionGene(key=(-20, 3), weight=-1.6994674904281264, enabled=True)
# 	DefaultConnectionGene(key=(-20, 323), weight=-0.536649574965969, enabled=False)
# 	DefaultConnectionGene(key=(-19, 0), weight=-0.6554916420874193, enabled=True)
# 	DefaultConnectionGene(key=(-19, 1), weight=-1.8994712271225698, enabled=True)
# 	DefaultConnectionGene(key=(-19, 2), weight=2.9184285933162584, enabled=True)
# 	DefaultConnectionGene(key=(-19, 323), weight=-0.3752110138382873, enabled=True)
# 	DefaultConnectionGene(key=(-18, 0), weight=0.27716297250272726, enabled=True)
# 	DefaultConnectionGene(key=(-18, 1), weight=0.4302240813997211, enabled=True)
# 	DefaultConnectionGene(key=(-18, 2), weight=2.5026939024528403, enabled=True)
# 	DefaultConnectionGene(key=(-18, 3), weight=0.6906581425915252, enabled=True)
# 	DefaultConnectionGene(key=(-18, 323), weight=-0.71354919143263, enabled=True)
# 	DefaultConnectionGene(key=(-17, 0), weight=2.304775390212414, enabled=True)
# 	DefaultConnectionGene(key=(-17, 1), weight=2.022070915642104, enabled=True)
# 	DefaultConnectionGene(key=(-17, 2), weight=0.4652986295076443, enabled=False)
# 	DefaultConnectionGene(key=(-17, 3), weight=-2.3627960653376427, enabled=False)
# 	DefaultConnectionGene(key=(-17, 323), weight=4.2358239761565875, enabled=True)
# 	DefaultConnectionGene(key=(-16, 0), weight=1.660161116674626, enabled=True)
# 	DefaultConnectionGene(key=(-16, 1), weight=0.07828245595975125, enabled=True)
# 	DefaultConnectionGene(key=(-16, 2), weight=0.6426146507740365, enabled=True)
# 	DefaultConnectionGene(key=(-16, 3), weight=-3.307060963573719, enabled=True)
# 	DefaultConnectionGene(key=(-16, 323), weight=-0.4074491456723568, enabled=True)
# 	DefaultConnectionGene(key=(-15, 0), weight=2.952685840474338, enabled=False)
# 	DefaultConnectionGene(key=(-15, 1), weight=-2.211256509999483, enabled=True)
# 	DefaultConnectionGene(key=(-15, 2), weight=1.343916250034429, enabled=True)
# 	DefaultConnectionGene(key=(-15, 323), weight=-1.6936939292825903, enabled=True)
# 	DefaultConnectionGene(key=(-14, 0), weight=0.7449238639598625, enabled=True)
# 	DefaultConnectionGene(key=(-14, 1), weight=-0.8728817612759885, enabled=False)
# 	DefaultConnectionGene(key=(-14, 2), weight=1.9229753943987842, enabled=True)
# 	DefaultConnectionGene(key=(-14, 3), weight=0.3107808417239118, enabled=True)
# 	DefaultConnectionGene(key=(-14, 323), weight=2.2927853928886406, enabled=True)
# 	DefaultConnectionGene(key=(-13, 0), weight=1.8524310520638279, enabled=True)
# 	DefaultConnectionGene(key=(-13, 2), weight=0.43181691609694733, enabled=True)
# 	DefaultConnectionGene(key=(-13, 3), weight=1.3865660458923748, enabled=True)
# 	DefaultConnectionGene(key=(-13, 323), weight=-2.183877531942619, enabled=True)
# 	DefaultConnectionGene(key=(-12, 0), weight=-0.42559225742185014, enabled=True)
# 	DefaultConnectionGene(key=(-12, 1), weight=-2.1254607180891356, enabled=True)
# 	DefaultConnectionGene(key=(-12, 2), weight=0.37801677695592284, enabled=True)
# 	DefaultConnectionGene(key=(-12, 3), weight=2.0923631491277703, enabled=True)
# 	DefaultConnectionGene(key=(-12, 323), weight=0.706327110343705, enabled=True)
# 	DefaultConnectionGene(key=(-11, 2), weight=1.3216926493815397, enabled=True)
# 	DefaultConnectionGene(key=(-11, 3), weight=2.5537297576516154, enabled=True)
# 	DefaultConnectionGene(key=(-11, 323), weight=2.0703501768377155, enabled=True)
# 	DefaultConnectionGene(key=(-10, 0), weight=1.3456046442113871, enabled=True)
# 	DefaultConnectionGene(key=(-10, 1), weight=1.8167687431826924, enabled=True)
# 	DefaultConnectionGene(key=(-10, 2), weight=-1.7556831304149987, enabled=False)
# 	DefaultConnectionGene(key=(-10, 3), weight=1.1351938512450843, enabled=True)
# 	DefaultConnectionGene(key=(-9, 0), weight=-0.44092409173890784, enabled=True)
# 	DefaultConnectionGene(key=(-9, 1), weight=2.8965551482433725, enabled=True)
# 	DefaultConnectionGene(key=(-9, 2), weight=3.0394056406529075, enabled=True)
# 	DefaultConnectionGene(key=(-9, 3), weight=0.7557496489199207, enabled=True)
# 	DefaultConnectionGene(key=(-9, 323), weight=0.15342594963935108, enabled=True)
# 	DefaultConnectionGene(key=(-8, 0), weight=-0.9140792850194428, enabled=True)
# 	DefaultConnectionGene(key=(-8, 1), weight=0.6218574907541973, enabled=True)
# 	DefaultConnectionGene(key=(-8, 2), weight=-0.7115160141596659, enabled=True)
# 	DefaultConnectionGene(key=(-8, 3), weight=1.0134391808759518, enabled=True)
# 	DefaultConnectionGene(key=(-8, 323), weight=0.7452313180789354, enabled=True)
# 	DefaultConnectionGene(key=(-7, 0), weight=2.0671752048073415, enabled=True)
# 	DefaultConnectionGene(key=(-7, 1), weight=3.5026078323038745, enabled=False)
# 	DefaultConnectionGene(key=(-7, 2), weight=0.32830331470371854, enabled=True)
# 	DefaultConnectionGene(key=(-7, 3), weight=-0.4054364396813238, enabled=True)
# 	DefaultConnectionGene(key=(-6, 0), weight=1.1060982828599872, enabled=False)
# 	DefaultConnectionGene(key=(-6, 1), weight=0.25155536036637394, enabled=False)
# 	DefaultConnectionGene(key=(-6, 2), weight=-1.1900903572479142, enabled=True)
# 	DefaultConnectionGene(key=(-5, 0), weight=-1.6497082387233923, enabled=True)
# 	DefaultConnectionGene(key=(-5, 1), weight=-0.22194448423926447, enabled=False)
# 	DefaultConnectionGene(key=(-5, 2), weight=0.2535063971116391, enabled=True)
# 	DefaultConnectionGene(key=(-5, 3), weight=1.969769982318105, enabled=True)
# 	DefaultConnectionGene(key=(-5, 323), weight=4.462227069139739, enabled=True)
# 	DefaultConnectionGene(key=(-4, 0), weight=-2.6729323865472554, enabled=True)
# 	DefaultConnectionGene(key=(-4, 1), weight=-1.0333979384845033, enabled=True)
# 	DefaultConnectionGene(key=(-4, 2), weight=1.8885286252917752, enabled=True)
# 	DefaultConnectionGene(key=(-4, 3), weight=0.27466387834958844, enabled=True)
# 	DefaultConnectionGene(key=(-4, 323), weight=2.748150915558973, enabled=True)
# 	DefaultConnectionGene(key=(-3, 0), weight=-1.2639873583542984, enabled=True)
# 	DefaultConnectionGene(key=(-3, 1), weight=3.530935384681441, enabled=True)
# 	DefaultConnectionGene(key=(-3, 2), weight=-0.3706456672860361, enabled=True)
# 	DefaultConnectionGene(key=(-3, 3), weight=-1.3076226490736083, enabled=True)
# 	DefaultConnectionGene(key=(-3, 323), weight=0.5019223482854128, enabled=True)
# 	DefaultConnectionGene(key=(-2, 0), weight=-2.0773551124285943, enabled=True)
# 	DefaultConnectionGene(key=(-2, 1), weight=0.7184369160211022, enabled=True)
# 	DefaultConnectionGene(key=(-2, 2), weight=-0.07896293052297931, enabled=True)
# 	DefaultConnectionGene(key=(-2, 3), weight=0.9087579474780628, enabled=True)
# 	DefaultConnectionGene(key=(-2, 323), weight=0.5915121148959829, enabled=True)
# 	DefaultConnectionGene(key=(-1, 0), weight=-0.3488472002047194, enabled=True)
# 	DefaultConnectionGene(key=(-1, 1), weight=0.3968786002870869, enabled=True)
# 	DefaultConnectionGene(key=(-1, 2), weight=-1.4066343613583896, enabled=False)
# 	DefaultConnectionGene(key=(-1, 3), weight=2.4427543560990412, enabled=True)
# 	DefaultConnectionGene(key=(-1, 323), weight=3.1655105328451105, enabled=True)
# 	DefaultConnectionGene(key=(0, 524), weight=-0.4435176374305571, enabled=False)
# 	DefaultConnectionGene(key=(323, 1), weight=0.32327617526426716, enabled=True)
# 	DefaultConnectionGene(key=(323, 2), weight=0.7897056288879161, enabled=True)
# 	DefaultConnectionGene(key=(323, 3), weight=-2.3266729778363175, enabled=True)
# 	DefaultConnectionGene(key=(524, 323), weight=-0.3668522457937223, enabled=True)
# 	DefaultConnectionGene(key=(874, 1), weight=-2.6709385100669047, enabled=True)

# %%
import os
import pickle
import neat
import gym
import numpy as np

# load the winner
with open('winner', 'rb') as f:
    c = pickle.load(f)

print('Loaded genome:')
print(c)

# Load the config file, which is assumed to live in
# the same directory as this script.
# local_dir = os.path.dirname(__file__)
# config_path = os.path.join(local_dir, 'config')
config_path = os.path.join('config', )
config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                     neat.DefaultSpeciesSet, neat.DefaultStagnation,
                     config_path)

net = neat.nn.FeedForwardNetwork.create(c, config)


env = gym.make("BipedalWalker-v3")
observation = env.reset()

done = False
while not done:
    action = net.activate(observation)

    observation, reward, done, info = env.step(action)
    env.render()
env.close()
# Out:
# Loaded genome:
# Key: 4594
# Fitness: 33.381096419944335
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=0.9975383684126703, response=1.0, activation=tanh, aggregation=sum)
# 	1 DefaultNodeGene(key=1, bias=1.9991927238204916, response=1.0, activation=tanh, aggregation=sum)
# 	2 DefaultNodeGene(key=2, bias=0.11947868123539673, response=1.0, activation=tanh, aggregation=sum)
# 	3 DefaultNodeGene(key=3, bias=-0.13281735159471736, response=1.0, activation=tanh, aggregation=sum)
# 	323 DefaultNodeGene(key=323, bias=-0.06666967237055872, response=1.0, activation=tanh, aggregation=sum)
# 	524 DefaultNodeGene(key=524, bias=-1.2530759943223775, response=1.0, activation=tanh, aggregation=sum)
# 	874 DefaultNodeGene(key=874, bias=-1.6921654578967358, response=1.0, activation=tanh, aggregation=sum)
# Connections:
# 	DefaultConnectionGene(key=(-24, 0), weight=-1.1406256184851231, enabled=True)
# 	DefaultConnectionGene(key=(-24, 1), weight=3.251320429755837, enabled=True)
# 	DefaultConnectionGene(key=(-24, 2), weight=-0.7870127911546994, enabled=True)
# 	DefaultConnectionGene(key=(-24, 3), weight=-0.8474898556497331, enabled=False)
# 	DefaultConnectionGene(key=(-24, 323), weight=0.059553780930359554, enabled=True)
# 	DefaultConnectionGene(key=(-24, 874), weight=-0.3468980411374187, enabled=False)
# 	DefaultConnectionGene(key=(-23, 0), weight=-0.47765379106018546, enabled=True)
# 	DefaultConnectionGene(key=(-23, 1), weight=-5.618403578773833, enabled=True)
# 	DefaultConnectionGene(key=(-23, 2), weight=0.584883378958578, enabled=True)
# 	DefaultConnectionGene(key=(-23, 3), weight=-0.1719380311727522, enabled=True)
# 	DefaultConnectionGene(key=(-23, 323), weight=0.23276897959209253, enabled=True)
# 	DefaultConnectionGene(key=(-22, 0), weight=0.9758133874088885, enabled=True)
# 	DefaultConnectionGene(key=(-22, 1), weight=2.7938161852456505, enabled=True)
# 	DefaultConnectionGene(key=(-22, 2), weight=0.2837549043133025, enabled=True)
# 	DefaultConnectionGene(key=(-22, 3), weight=2.5154866995868304, enabled=False)
# 	DefaultConnectionGene(key=(-22, 323), weight=0.14003497549211444, enabled=True)
# 	DefaultConnectionGene(key=(-21, 0), weight=1.4725031121176215, enabled=True)
# 	DefaultConnectionGene(key=(-21, 1), weight=2.323707686383643, enabled=True)
# 	DefaultConnectionGene(key=(-21, 2), weight=0.7839820739530552, enabled=True)
# 	DefaultConnectionGene(key=(-21, 3), weight=1.0975737470844278, enabled=True)
# 	DefaultConnectionGene(key=(-21, 323), weight=1.3128739292421425, enabled=True)
# 	DefaultConnectionGene(key=(-20, 0), weight=3.7233536656403925, enabled=True)
# 	DefaultConnectionGene(key=(-20, 1), weight=0.43802851629688977, enabled=False)
# 	DefaultConnectionGene(key=(-20, 2), weight=-3.537614287824832, enabled=False)
# 	DefaultConnectionGene(key=(-20, 3), weight=-1.6994674904281264, enabled=True)
# 	DefaultConnectionGene(key=(-20, 323), weight=-0.536649574965969, enabled=False)
# 	DefaultConnectionGene(key=(-19, 0), weight=-0.6554916420874193, enabled=True)
# 	DefaultConnectionGene(key=(-19, 1), weight=-1.8994712271225698, enabled=True)
# 	DefaultConnectionGene(key=(-19, 2), weight=2.9184285933162584, enabled=True)
# 	DefaultConnectionGene(key=(-19, 323), weight=-0.3752110138382873, enabled=True)
# 	DefaultConnectionGene(key=(-18, 0), weight=0.27716297250272726, enabled=True)
# 	DefaultConnectionGene(key=(-18, 1), weight=0.4302240813997211, enabled=True)
# 	DefaultConnectionGene(key=(-18, 2), weight=2.5026939024528403, enabled=True)
# 	DefaultConnectionGene(key=(-18, 3), weight=0.6906581425915252, enabled=True)
# 	DefaultConnectionGene(key=(-18, 323), weight=-0.71354919143263, enabled=True)
# 	DefaultConnectionGene(key=(-17, 0), weight=2.304775390212414, enabled=True)
# 	DefaultConnectionGene(key=(-17, 1), weight=2.022070915642104, enabled=True)
# 	DefaultConnectionGene(key=(-17, 2), weight=0.4652986295076443, enabled=False)
# 	DefaultConnectionGene(key=(-17, 3), weight=-2.3627960653376427, enabled=False)
# 	DefaultConnectionGene(key=(-17, 323), weight=4.2358239761565875, enabled=True)
# 	DefaultConnectionGene(key=(-16, 0), weight=1.660161116674626, enabled=True)
# 	DefaultConnectionGene(key=(-16, 1), weight=0.07828245595975125, enabled=True)
# 	DefaultConnectionGene(key=(-16, 2), weight=0.6426146507740365, enabled=True)
# 	DefaultConnectionGene(key=(-16, 3), weight=-3.307060963573719, enabled=True)
# 	DefaultConnectionGene(key=(-16, 323), weight=-0.4074491456723568, enabled=True)
# 	DefaultConnectionGene(key=(-15, 0), weight=2.952685840474338, enabled=False)
# 	DefaultConnectionGene(key=(-15, 1), weight=-2.211256509999483, enabled=True)
# 	DefaultConnectionGene(key=(-15, 2), weight=1.343916250034429, enabled=True)
# 	DefaultConnectionGene(key=(-15, 323), weight=-1.6936939292825903, enabled=True)
# 	DefaultConnectionGene(key=(-14, 0), weight=0.7449238639598625, enabled=True)
# 	DefaultConnectionGene(key=(-14, 1), weight=-0.8728817612759885, enabled=False)
# 	DefaultConnectionGene(key=(-14, 2), weight=1.9229753943987842, enabled=True)
# 	DefaultConnectionGene(key=(-14, 3), weight=0.3107808417239118, enabled=True)
# 	DefaultConnectionGene(key=(-14, 323), weight=2.2927853928886406, enabled=True)
# 	DefaultConnectionGene(key=(-13, 0), weight=1.8524310520638279, enabled=True)
# 	DefaultConnectionGene(key=(-13, 2), weight=0.43181691609694733, enabled=True)
# 	DefaultConnectionGene(key=(-13, 3), weight=1.3865660458923748, enabled=True)
# 	DefaultConnectionGene(key=(-13, 323), weight=-2.183877531942619, enabled=True)
# 	DefaultConnectionGene(key=(-12, 0), weight=-0.42559225742185014, enabled=True)
# 	DefaultConnectionGene(key=(-12, 1), weight=-2.1254607180891356, enabled=True)
# 	DefaultConnectionGene(key=(-12, 2), weight=0.37801677695592284, enabled=True)
# 	DefaultConnectionGene(key=(-12, 3), weight=2.0923631491277703, enabled=True)
# 	DefaultConnectionGene(key=(-12, 323), weight=0.706327110343705, enabled=True)
# 	DefaultConnectionGene(key=(-11, 2), weight=1.3216926493815397, enabled=True)
# 	DefaultConnectionGene(key=(-11, 3), weight=2.5537297576516154, enabled=True)
# 	DefaultConnectionGene(key=(-11, 323), weight=2.0703501768377155, enabled=True)
# 	DefaultConnectionGene(key=(-10, 0), weight=1.3456046442113871, enabled=True)
# 	DefaultConnectionGene(key=(-10, 1), weight=1.8167687431826924, enabled=True)
# 	DefaultConnectionGene(key=(-10, 2), weight=-1.7556831304149987, enabled=False)
# 	DefaultConnectionGene(key=(-10, 3), weight=1.1351938512450843, enabled=True)
# 	DefaultConnectionGene(key=(-9, 0), weight=-0.44092409173890784, enabled=True)
# 	DefaultConnectionGene(key=(-9, 1), weight=2.8965551482433725, enabled=True)
# 	DefaultConnectionGene(key=(-9, 2), weight=3.0394056406529075, enabled=True)
# 	DefaultConnectionGene(key=(-9, 3), weight=0.7557496489199207, enabled=True)
# 	DefaultConnectionGene(key=(-9, 323), weight=0.15342594963935108, enabled=True)
# 	DefaultConnectionGene(key=(-8, 0), weight=-0.9140792850194428, enabled=True)
# 	DefaultConnectionGene(key=(-8, 1), weight=0.6218574907541973, enabled=True)
# 	DefaultConnectionGene(key=(-8, 2), weight=-0.7115160141596659, enabled=True)
# 	DefaultConnectionGene(key=(-8, 3), weight=1.0134391808759518, enabled=True)
# 	DefaultConnectionGene(key=(-8, 323), weight=0.7452313180789354, enabled=True)
# 	DefaultConnectionGene(key=(-7, 0), weight=2.0671752048073415, enabled=True)
# 	DefaultConnectionGene(key=(-7, 1), weight=3.5026078323038745, enabled=False)
# 	DefaultConnectionGene(key=(-7, 2), weight=0.32830331470371854, enabled=True)
# 	DefaultConnectionGene(key=(-7, 3), weight=-0.4054364396813238, enabled=True)
# 	DefaultConnectionGene(key=(-6, 0), weight=1.1060982828599872, enabled=False)
# 	DefaultConnectionGene(key=(-6, 1), weight=0.25155536036637394, enabled=False)
# 	DefaultConnectionGene(key=(-6, 2), weight=-1.1900903572479142, enabled=True)
# 	DefaultConnectionGene(key=(-5, 0), weight=-1.6497082387233923, enabled=True)
# 	DefaultConnectionGene(key=(-5, 1), weight=-0.22194448423926447, enabled=False)
# 	DefaultConnectionGene(key=(-5, 2), weight=0.2535063971116391, enabled=True)
# 	DefaultConnectionGene(key=(-5, 3), weight=1.969769982318105, enabled=True)
# 	DefaultConnectionGene(key=(-5, 323), weight=4.462227069139739, enabled=True)
# 	DefaultConnectionGene(key=(-4, 0), weight=-2.6729323865472554, enabled=True)
# 	DefaultConnectionGene(key=(-4, 1), weight=-1.0333979384845033, enabled=True)
# 	DefaultConnectionGene(key=(-4, 2), weight=1.8885286252917752, enabled=True)
# 	DefaultConnectionGene(key=(-4, 3), weight=0.27466387834958844, enabled=True)
# 	DefaultConnectionGene(key=(-4, 323), weight=2.748150915558973, enabled=True)
# 	DefaultConnectionGene(key=(-3, 0), weight=-1.2639873583542984, enabled=True)
# 	DefaultConnectionGene(key=(-3, 1), weight=3.530935384681441, enabled=True)
# 	DefaultConnectionGene(key=(-3, 2), weight=-0.3706456672860361, enabled=True)
# 	DefaultConnectionGene(key=(-3, 3), weight=-1.3076226490736083, enabled=True)
# 	DefaultConnectionGene(key=(-3, 323), weight=0.5019223482854128, enabled=True)
# 	DefaultConnectionGene(key=(-2, 0), weight=-2.0773551124285943, enabled=True)
# 	DefaultConnectionGene(key=(-2, 1), weight=0.7184369160211022, enabled=True)
# 	DefaultConnectionGene(key=(-2, 2), weight=-0.07896293052297931, enabled=True)
# 	DefaultConnectionGene(key=(-2, 3), weight=0.9087579474780628, enabled=True)
# 	DefaultConnectionGene(key=(-2, 323), weight=0.5915121148959829, enabled=True)
# 	DefaultConnectionGene(key=(-1, 0), weight=-0.3488472002047194, enabled=True)
# 	DefaultConnectionGene(key=(-1, 1), weight=0.3968786002870869, enabled=True)
# 	DefaultConnectionGene(key=(-1, 2), weight=-1.4066343613583896, enabled=False)
# 	DefaultConnectionGene(key=(-1, 3), weight=2.4427543560990412, enabled=True)
# 	DefaultConnectionGene(key=(-1, 323), weight=3.1655105328451105, enabled=True)
# 	DefaultConnectionGene(key=(0, 524), weight=-0.4435176374305571, enabled=False)
# 	DefaultConnectionGene(key=(323, 1), weight=0.32327617526426716, enabled=True)
# 	DefaultConnectionGene(key=(323, 2), weight=0.7897056288879161, enabled=True)
# 	DefaultConnectionGene(key=(323, 3), weight=-2.3266729778363175, enabled=True)
# 	DefaultConnectionGene(key=(524, 323), weight=-0.3668522457937223, enabled=True)
# 	DefaultConnectionGene(key=(874, 1), weight=-2.6709385100669047, enabled=True)
