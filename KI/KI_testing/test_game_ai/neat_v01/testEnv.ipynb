# %%
from ipynb.fs.full.neatFile import *

if __name__ == '__main__':
    run()
# Out:
#  ****** Running generation 0 ******
#
# Population's average fitness: -200.00000 stdev: 0.00000
# Best fitness: -200.00000 - size: (3, 6) - species 1 - id 1
# Average adjusted fitness: 0.000
# Mean genetic distance 1.297, standard deviation 0.323
# Population of 300 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    0   300   -200.0    0.000     0
# Total extinctions: 0
# Generation time: 2.884 sec
#
#  ****** Running generation 1 ******
#
# Population's average fitness: -199.94167 stdev: 1.00868
# Best fitness: -182.50000 - size: (3, 5) - species 1 - id 353
# Average adjusted fitness: 0.003
# Mean genetic distance 1.411, standard deviation 0.351
# Population of 300 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    1   300   -182.5    0.003     0
# Total extinctions: 0
# Generation time: 1.499 sec (2.191 average)
#
#  ****** Running generation 2 ******
#
# Population's average fitness: -199.85000 stdev: 2.59374
# Best fitness: -155.00000 - size: (3, 5) - species 1 - id 353
# Average adjusted fitness: 0.003
# Mean genetic distance 1.479, standard deviation 0.392
# Population of 300 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    2   300   -155.0    0.003     0
# Total extinctions: 0
# Generation time: 1.522 sec (1.968 average)
#
#  ****** Running generation 3 ******
#
# Population's average fitness: -199.89833 stdev: 1.75798
# Best fitness: -169.50000 - size: (3, 5) - species 1 - id 353
# Average adjusted fitness: 0.003
# Mean genetic distance 1.498, standard deviation 0.353
# Population of 300 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    3   300   -169.5    0.003     1
# Total extinctions: 0
# Generation time: 1.545 sec (1.862 average)
#
#  ****** Running generation 4 ******
#
# Population's average fitness: -199.90333 stdev: 1.67152
# Best fitness: -171.00000 - size: (3, 5) - species 1 - id 353
# Average adjusted fitness: 0.003
# Mean genetic distance 1.554, standard deviation 0.379
# Population of 300 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    4   300   -171.0    0.003     2
# Total extinctions: 0
# Generation time: 1.527 sec (1.795 average)
#
#  ****** Running generation 5 ******
#
# Population's average fitness: -199.89167 stdev: 1.87326
# Best fitness: -167.50000 - size: (3, 5) - species 1 - id 353
# Average adjusted fitness: 0.003
# Mean genetic distance 1.584, standard deviation 0.369
# Population of 300 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    5   300   -167.5    0.003     3
# Total extinctions: 0
# Generation time: 1.506 sec (1.747 average)
#
#  ****** Running generation 6 ******
#
# Population's average fitness: -200.00000 stdev: 0.00000
# Best fitness: -200.00000 - size: (3, 5) - species 1 - id 353
# Average adjusted fitness: 0.000
# Mean genetic distance 1.638, standard deviation 0.347
# Population of 300 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    6   300   -200.0    0.000     4
# Total extinctions: 0
# Generation time: 1.502 sec (1.712 average)
#
#  ****** Running generation 7 ******
#
# Population's average fitness: -200.00000 stdev: 0.00000
# Best fitness: -200.00000 - size: (3, 6) - species 1 - id 1
# Average adjusted fitness: 0.000
# Mean genetic distance 1.681, standard deviation 0.402
# Population of 300 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    7   300   -200.0    0.000     5
# Total extinctions: 0
# Generation time: 1.498 sec (1.685 average)
#
#  ****** Running generation 8 ******
#
# Population's average fitness: -200.00000 stdev: 0.00000
# Best fitness: -200.00000 - size: (3, 6) - species 1 - id 1
# Average adjusted fitness: 0.000
# Mean genetic distance 1.728, standard deviation 0.401
# Population of 300 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    8   300   -200.0    0.000     6
# Total extinctions: 0
# Generation time: 1.482 sec (1.663 average)
#
#  ****** Running generation 9 ******
#
# Population's average fitness: -200.00000 stdev: 0.00000
# Best fitness: -200.00000 - size: (3, 6) - species 1 - id 1
# Average adjusted fitness: 0.000
# Mean genetic distance 1.787, standard deviation 0.402
# Population of 300 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    9   300   -200.0    0.000     7
# Total extinctions: 0
# Generation time: 1.484 sec (1.645 average)
#
#  ****** Running generation 10 ******
#
# Population's average fitness: -200.00000 stdev: 0.00000
# Best fitness: -200.00000 - size: (3, 6) - species 1 - id 1
# Average adjusted fitness: 0.000
# Mean genetic distance 1.821, standard deviation 0.389
# Population of 300 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   10   300   -200.0    0.000     8
# Total extinctions: 0
# Generation time: 1.474 sec (1.504 average)
#
#  ****** Running generation 11 ******
#
# Population's average fitness: -199.75667 stdev: 2.99819
# Best fitness: -158.50000 - size: (4, 2) - species 1 - id 3312
# Average adjusted fitness: 0.006
# Mean genetic distance 1.847, standard deviation 0.380
# Population of 300 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   11   300   -158.5    0.006     9
# Total extinctions: 0
# Generation time: 1.488 sec (1.503 average)
#
#  ****** Running generation 12 ******
#
# Population's average fitness: -199.89000 stdev: 1.90208
# Best fitness: -167.00000 - size: (4, 2) - species 1 - id 3312
# Average adjusted fitness: 0.003
# Mean genetic distance 1.907, standard deviation 0.385
# Population of 300 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   12   300   -167.0    0.003    10
# Total extinctions: 0
# Generation time: 1.498 sec (1.500 average)
#
#  ****** Running generation 13 ******
#
# Population's average fitness: -199.77000 stdev: 2.81018
# Best fitness: -164.00000 - size: (4, 2) - species 1 - id 3312
# Average adjusted fitness: 0.006
# Mean genetic distance 1.936, standard deviation 0.370
# Population of 300 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   13   300   -164.0    0.006    11
# Total extinctions: 0
# Generation time: 1.504 sec (1.496 average)
#
#  ****** Running generation 14 ******
#
# Population's average fitness: -199.61500 stdev: 5.05331
# Best fitness: -119.50000 - size: (4, 2) - species 1 - id 3312
# Average adjusted fitness: 0.005
# Mean genetic distance 2.219, standard deviation 0.600
# Population of 300 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   14   288   -119.5    0.005     0
#      2    0    12       --       --     0
# Total extinctions: 0
# Generation time: 1.453 sec (1.489 average)
#
#  ****** Running generation 15 ******
#
# Population's average fitness: -198.85500 stdev: 8.71358
# Best fitness: -109.50000 - size: (3, 1) - species 1 - id 4643
# Average adjusted fitness: 0.007
# Mean genetic distance 2.250, standard deviation 0.590
# Population of 300 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   15   272   -109.5    0.013     0
#      2    1    28   -200.0    0.000     0
# Total extinctions: 0
# Generation time: 1.480 sec (1.486 average)
#
#  ****** Running generation 16 ******
#
# Population's average fitness: -197.94333 stdev: 11.93210
# Best fitness: -107.50000 - size: (3, 1) - species 1 - id 5046
# Average adjusted fitness: 0.012
# Mean genetic distance 2.279, standard deviation 0.593
# Population of 300 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   16   283   -107.5    0.025     0
#      2    2    17   -200.0    0.000     1
# Total extinctions: 0
# Generation time: 1.450 sec (1.481 average)
#
#  ****** Running generation 17 ******
#
# Population's average fitness: -197.68500 stdev: 11.76676
# Best fitness: -124.00000 - size: (3, 1) - species 1 - id 5324
# Average adjusted fitness: 0.016
# Mean genetic distance 2.315, standard deviation 0.572
# Population of 300 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   17   270   -124.0    0.032     1
#      2    3    13   -200.0    0.000     2
#      3    0    17       --       --     0
# Total extinctions: 0
# Generation time: 1.441 sec (1.475 average)
#
#  ****** Running generation 18 ******
# Population's average fitness: -197.48500 stdev: 13.41395
# Best fitness: -91.00000 - size: (4, 2) - species 1 - id 5199
# Average adjusted fitness: 0.034
# Mean genetic distance 2.228, standard deviation 0.582
# Population of 300 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   18   186    -91.0    0.021     0
#      2    4     2   -200.0    0.000     3
#      3    1   100   -125.0    0.080     0
#      4    0    12       --       --     0
# Total extinctions: 0
# Generation time: 1.424 sec (1.470 average)
#
#  ****** Running generation 19 ******
#
# Population's average fitness: -197.08333 stdev: 13.44810
# Best fitness: -87.00000 - size: (3, 1) - species 1 - id 5870
#
# Best individual in generation 19 meets fitness threshold - complexity: (3, 1)
# Key: 5870
# Fitness: -87.0
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=-0.5745957431093143, response=1.0, activation=tanh, aggregation=sum)
# 	1 DefaultNodeGene(key=1, bias=-0.09316038641985555, response=1.0, activation=tanh, aggregation=sum)
# 	2 DefaultNodeGene(key=2, bias=-0.008600820705205403, response=1.0, activation=tanh, aggregation=sum)
# Connections:
# 	DefaultConnectionGene(key=(-2, 2), weight=5.498313366075977, enabled=True)

# %%
import os
import pickle
import neat
import gym
import numpy as np

# load the winner
with open('winner', 'rb') as f:
    c = pickle.load(f)

print('Loaded genome:')
print(c)

# Load the config file, which is assumed to live in
# the same directory as this script.
# local_dir = os.path.dirname(__file__)
# config_path = os.path.join(local_dir, 'config')
config_path = os.path.join('config', )
config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                     neat.DefaultSpeciesSet, neat.DefaultStagnation,
                     config_path)

net = neat.nn.FeedForwardNetwork.create(c, config)


env = gym.make("MountainCar-v0")
observation = env.reset()

done = False
while not done:
    action = np.argmax(net.activate(observation))

    observation, reward, done, info = env.step(action)
    env.render()
# Out:
# Loaded genome:
# Key: 5870
# Fitness: -87.0
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=-0.5745957431093143, response=1.0, activation=tanh, aggregation=sum)
# 	1 DefaultNodeGene(key=1, bias=-0.09316038641985555, response=1.0, activation=tanh, aggregation=sum)
# 	2 DefaultNodeGene(key=2, bias=-0.008600820705205403, response=1.0, activation=tanh, aggregation=sum)
# Connections:
# 	DefaultConnectionGene(key=(-2, 2), weight=5.498313366075977, enabled=True)

# %%
env.close()
